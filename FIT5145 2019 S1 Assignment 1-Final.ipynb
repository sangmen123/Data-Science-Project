# %% [markdown]
# # FIT5145 - Introduction to Data Science
# ## Assignment 1
#
# The aim of this assignment is to investigate and visualise data using various data science tools. It will test your ability to:
# 1. read data files in Python and extract related data from those files;
# 2. wrangle and process data;
# 3. use various graphical and non-graphical tools to perform exploratory data analysis and visualisation;
# 4. use basic tools for managing and processing big data; and
# 5. communicate your findings in your report.
#
# You will need to submit two files:
# 1. The Python code as a Jupyter notebook file that you wrote to analyse and plot the data.
# 2. A PDF of your Jupyter notebook file containing your answers (code, figures and answers to all the questions). Make sure to include screenshots/images of the graphs you generate in order to justify your answers to all the questions. Marks will be assigned to PDF reports based on their correctness and clarity. -- For example, higher marks will be given to PDF reports containing graphs with appropriately labelled axes.
#
# IMPORTANT NOTE - Zip file submission will have a penalty of 10%. Do not submit the separate files requested above together in one Zip file. As indicated in the rubric, marks will be deducted for this because it adds significantly to the time it takes for the markers to open up and access your assignments given that there are many students in this class.
#
# ## Tasks
#
# There are two tasks that you need to complete for this assignment, Task A and Task B. You need to use Python to complete the tasks.
#
# ## Task A - Who are Data Scientists? Data Scientist Demographics
#
# *'What does a does a Data Scientist look like?'*, *'What is Data Science exactly?'*, *'Is Python or R better to learn for beginners?'*, *'Do you have to have a degree in Computer Science to be a Data Scientist?'* and *'Do data scientists earn as much as I think?'*.
#
# Anjul Bhambri, the Vice Preseident of big data prodcts at IBM says this
#
# >*‘A data scientist is somebody who is inquisitive, who can stare at data and spot trends. It’s almost like a Renaissance individual who really wants to learn and bring change to an organisation.’*
#
# In this course, you have learned that the diversity in definitions, skill sets, tools, applications and knowledge domains that make data science challenging to define precisely. By completing the following questions, we hope you can get a more precise understanding.
#
# **The Data**
#
# Kaggle is the home of analytics and predictive modelling competitions. Data Science enthusiast, beginners to professionals, compete to create the best predictive models using datasets uploaded both by individuals and companies looking for insights. Prizes can be as high as $3 million US. In late 2017 a survey of Kaggle users was conducted and received over 16,700 responses. The dataset was, of course, made public and many insights have emerged since. We have taken a portion of the data set and heavily modified the data. Both to clean the data, a significant component of data science and to ensure original assignment submission.
#
# **Your Job**
#
# The following notebook has been constructed to provide you with directions (<span style="color: blue">blue</span>), assessed questions (<span style="color: brown">brown</span>) and background information. Responses to both blue directions and brown questions are assessable.
#
# You will be required to write your own code. Underneath direction boxes, there will be empty cells with the comment <span style="color: green">#Your code</span>. Insert new cells under this cell if required.
#
# To respond to questions you should double click on the cell beneath each question with the comment <span style="color: green">Answer</span>.
#
# Please note, your commenting and adherence to Python code standards will be marked. This notebook has been designed to give you a template for how we expect Python Notebooks to be submitted for assessment. If you require further information on Python standards, please visit https://www.python.org/dev/peps/pep-0008/
# Do not change any of the directions or answer boxes, the order of questions, order of code entry cells or the name of the input files.
#
# **The Files**
#
# - *multipleChoiceResponses.csv * : Participants' answers to multiple choice questions. Each column contains the answers of one respondent to a specific question.
# - *conversionRates.csv* : Currency conversion rates to USD.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# ** Your Information**
# Enter your information in the following cell. Please make sure you specify what version of python you are using as your tutor may not be using the same version and will adjust your code accordingly.

# %% [markdown]
# ## Student Information
# <a id="Student Information"></a>
# Please enter your details here.
# #### Name: Sangamesh Surendranathan Menon
# #### Student number: 29819857
# #### Tutorial Day and Time: Monday 12-2 PM
# #### Tutor: Zhinoos Razavi Hesabi
# #### Environment: Python *(what version of python you are using)* and *Distribution (i.e. Anaconda 5.3.0 (64-bit))*

# %% [markdown]
# # Table of contents
#
# * [Student Information](#Student Information)
# * [1. Demographic analysis](#demographics)
#    * [1.1. Age](#age)
#    * [1.2. Gender](#gender)
#    * [1.3. Country](#country)
# * [2. Education](#education)
#     * [2.1. Formal education](#formal)
# * [3. Employment](#employment)
#     * [3.1. Employment Status](#status)
# * [4. Salary](#salary)
#     * [4.1. Salary overview](#overview)
#     * [4.2. Salary by country](#countrysal)
#     * [4.3. Salary and gender](#gender_salary)
#     * [4.4. Salary and formal education](#education_salary)
#     * [4.5. Salary and job](#salary_job)
# * [5. Predicting Salary](#pred)

# %% [markdown]
# ## 0. Load your libraries and files
# <a id="Load data"></a>
# ***

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 1. ** Load your libraries and files**
#
# This assesment will be conducted using pandas. You will also be required to create visualisations. We recomend Seaborn which is more visually appealing than matplotlib. However, you may choose either. For further information on Seaborn visit https://seaborn.pydata.org/
#
# *Hint: Remember to comment what each library does.*

# %%
# Your code
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#seaborn is useful for visual statistical graphics
multiple_choice = pd.read_csv('data/multipleChoiceResponses.csv')
conversion_rate = pd.read_csv('data/conversionRates.csv')
multiple_choice.head()
# Out:
#   GenderSelect    Country  Age    EmploymentStatus      CurrentJobTitleSelect  \
# 0         Male  Argentina   26  Employed full-time           Business Analyst
# 1         Male  Argentina   25  Employed full-time         Computer Scientist
# 2         Male  Argentina   24  Employed full-time  Machine Learning Engineer
# 3         Male  Argentina   25  Employed full-time  Machine Learning Engineer
# 4       Female  Australia   37  Employed part-time               Data Analyst
#
#   LanguageRecommendationSelect    FormalEducation  \
# 0                          SQL  Bachelor's degree
# 1                       Python  Bachelor's degree
# 2                       Python  Bachelor's degree
# 3                       Python  Bachelor's degree
# 4                          SQL  Bachelor's degree
#
#                                          MajorSelect  CompensationAmount  \
# 0                                              Other             18000.0
# ...

# %% [markdown]
# ## 1. Demographic Analysis
# <a id="demographics"></a>
# ***
# ##### So what does a data scientist look like?
#
# Let's get a general understanding of the characteristics of the survey participants. Demographic overviews are a standard way to start an exploration of survey data. The types of participants can heavily affect the survey responses.
#
# ### 1.1 Age
# <a id="age"></a>
# Visualisation is a quick and easy way to gain an overview of the data. One method is through a boxplot. Boxplots are a way to show the distribution of numerical data and display the five descriptive statistics: minimum, first quartile, median, third quartile, and maximum. Outliers should also be shown.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 2 Create a box plot showing the age of all the participants.
#
# Your plot must have labels for each axis, a title, numerical points for the age axis and also show the outliers.

# %%
# Your code
sns.boxplot(x=multiple_choice['Age']).set_title("Age of data science survey participants")
# Out:
# Text(0.5,1,'Age of data science survey participants')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 3. Calculate the five descriptive statistics as shown on the boxplot, as well as the mean
#
# Round your answer to the nearest whole number.

# %%
# Your code
mean = round(multiple_choice['Age'].mean())
first_quartile = round(multiple_choice['Age'].quantile(0.25))
third_quartile = round(multiple_choice['Age'].quantile(0.75))
median = round(multiple_choice['Age'].median())
minimum = round(multiple_choice['Age'].min())
maximum = round(multiple_choice['Age'].max())
print(mean)
print(first_quartile)
print(third_quartile)
print(median)
print(minimum)
print(maximum)
# Out:
# 34
# 27
# 39
# 32
# 20
# 78

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Mean: 34,
# First Quartile: 27,
# Third Quartile: 39,
# Median: 32,
# Minimum: 20,
# Maximum: 78

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 4. Looking at the boxplot what general conclusion can you make about the age of the participants?
#
# You must explain your answer concerning the median, minimum and maximum age of the respondents. You must also make mention of the outliers if there are any.

# %% [markdown]
# <span style="color: green">**Answer**</span>
# By looking at the boxplot we can say that most of the participants in this survey are aged between 20 and around 56. The average age of the survey participants are around 34 years and the median is 32. The youngest participant of this survey is 20 and the oldest is 78, which in this case is an outlier.

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 5. Regardless of the errors that the data show, we are interested in working-age data scientists, aged between 18 and 65.
#
# How many respondents were under 18 or over 65?

# %%
# Your code
total_participants = multiple_choice[(multiple_choice['Age'] < 18) | (multiple_choice['Age'] > 65) & (multiple_choice['CurrentJobTitleSelect'] == 'Data Scientist')]
print(total_participants['Age'].count())
# Out:
# 4

# %% [markdown]
# <span style="color: green">**Answer**</span>
# There are 4 participants who are data scientists and were under 18 and over 65 years of age

# %% [markdown]
# ### 1.2 Gender
# <a id="gender"></a>
# We are interested in the gender of respondents. Within the STEM fields, there are more males than females or other genders. In 2016 the Office of the chief scientist found that women held only 25% of jobs in STEM. Let's see how data science compares.

# %% [markdown]
#  <div class="alert alert-block alert-info">
#
# 6. Plot the gender distribution of survey participants.

# %%
# Your code

sns.countplot(x=multiple_choice['GenderSelect']).set_title("Bar chart for gender of participants")
# Out:
# Text(0.5,1,'Bar chart for gender of participants')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
#
# 7. What percentage of respondants were men? What percentage of respondants were women?

# %%
# Your code
men = multiple_choice[(multiple_choice['GenderSelect'] == 'Male')].count()
total_participants = multiple_choice['GenderSelect'].count()
percentage_men = round((men / total_participants) * 100)
print(percentage_men['GenderSelect'])
wommen = multiple_choice[(multiple_choice['GenderSelect'] == 'Female')].count()
percentage_women = round((wommen / total_participants) * 100)
print(percentage_women['GenderSelect'])
# Out:
# 85.0
# 14.0

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Men 85%,
# Women 14%

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 8. Let's see if there is any relationship between age and gender.
#
# Create a box plot showing the age of all the participants according to gender.
#
# Include the response 'Different identity' in your plot.

# %%
# Your code
sns.boxplot(x=multiple_choice['GenderSelect'], y=multiple_choice['Age']).set_title("Age of survey participants according to gender")
# Out:
# Text(0.5,1,'Age of survey participants according to gender')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
#
# 9. What comments can you make about the relationship between the age and gender of the respondents?
#
# Hint: You need to determine the numeric descriptive statistics

# %%
# Your code
gender_group = multiple_choice.groupby(['GenderSelect'])['Age']
mean = round(gender_group.mean())
median = round(gender_group.median())
first_quartile = round(gender_group.quantile(0.25))
third_quartile = round(gender_group.quantile(0.75))
minimum = round(gender_group.min())
maximum = round(gender_group.max())

print(mean)
print(first_quartile)
print(third_quartile)
print(median)
print(minimum)
print(maximum)
# Out:
# GenderSelect
# A different identity    35.0
# Female                  33.0
# Male                    35.0
# Name: Age, dtype: float64
# GenderSelect
# A different identity    28.0
# Female                  27.0
# Male                    27.0
# Name: Age, dtype: float64
# GenderSelect
# A different identity    38.0
# Female                  37.0
# Male                    40.0
# Name: Age, dtype: float64
# GenderSelect
# A different identity    32
# Female                  30
# Male                    32
# Name: Age, dtype: int64
# GenderSelect
# A different identity    22
# Female                  20
# Male                    20
# Name: Age, dtype: int64
# GenderSelect
# A different identity    68
# Female                  62
# Male                    78
# Name: Age, dtype: int64

# %% [markdown]
# <span style="color: green">**Answer**</span>

# %% [markdown]
# ### 1.3 Country
# <a id="country"></a>
# We know that people practise data science all over the world. The United States is thought of as a 'hub' of commercial data science as well as research followed by the United Kingdom and Germany.
#
# Because the field is evolving so quickly, it may be that these perceptions, formed in the late 2000s are now inaccurate. So let's find out where data scientists live.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 10. Create a bar graph of the respondants according to which country they are from.
#
# Find the percentage of respondants from the top 5 countries

# %%
# Your code
graph = sns.countplot(y=multiple_choice['Country']).set_title("Bar chart of participants based on country")
plt.rcParams["figure.figsize"] = (14, 20)
plt.rcParams["xtick.labelsize"] = 15
plt.rcParams["xtick.labelsize"] = 15


countries =  multiple_choice.groupby(['Country'])

total_count = multiple_choice['Country'].count()
print(total_count)

print(countries['Country'].count().sort_values(ascending=False).head())

US_percent = round((countries['Country'].count().sort_values(ascending=False).head()[0]/total_count) * 100)
India_percent = round((countries['Country'].count().sort_values(ascending=False).head()[1]/total_count) * 100)
UK_percent = round((countries['Country'].count().sort_values(ascending=False).head()[2]/total_count) * 100)
Germany_percent = round((countries['Country'].count().sort_values(ascending=False).head()[3]/total_count) * 100)
Brazil_percent = round((countries['Country'].count().sort_values(ascending=False).head()[4]/total_count) * 100)
print(US_percent)
print(India_percent)
print(UK_percent)
print(Germany_percent)
print(Brazil_percent)
# Out:
# 3540
# Country
# United States     1126
# India              431
# United Kingdom     151
# Germany            130
# Brazil             127
# Name: Country, dtype: int64
# 32.0
# 12.0
# 4.0
# 4.0
# 4.0

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Percentages of the top 5 countries:
# US 32%,
# India 12%,
# UK 4%,
# Germany 4%,
# Brazil 4%

# %% [markdown]
#  <div class="alert alert-block alert-warning">
#
# 11. What comments can you make about our previous comments on the United States, United Kingdom and Europe?
#
# Are the majority of data scientists now likely to come from those countries?

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Based on the graph and the top 5 countries, we can conclude that the majority of data scientists are in the United States with 32% responsdents. However, after US comes India with 12% and then comes UK, Germany and Brazil with 4% respectively. Hence based on the given data, we can conclude that US has the highest number of data scientists, but we cannot conclude that the UK and Europe have most number of data scientists

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 12. Now that we have another demographic variable, let's see if there is any relationship between country, age and gender. We are specifically interested in the United States, India, United Kingdom, Germany and of course Australia!
#
#
# Write code to output the mean and median age for United States, India, United Kingdom, Germany and Australia.
#
# Hint: You may need to create a copy or slice.

# %%
# Your Code
country_gender = multiple_choice.groupby(['Country','GenderSelect'])['Age']
mean = round(country_gender.mean())
median = round(country_gender.median())
print('United States mean age:')
print(mean['United States'])
print("")
print('India mean age:')
print(mean['India'])
print("")
print('United Kingdom mean age:')
print(mean['United Kingdom'])
print("")
print('Germany mean age:')
print(mean['Germany'])
print("")
print('Australia mean age:')
print(mean['Australia'])
print("")
print('United States median age:')
print(median['United States'])
print("")
print('India median age:')
print(median['India'])
print("")
print('United Kingdom median age:')
print(median['United Kingdom'])
print("")
print('Germany median age:')
print(median['Germany'])
print("")
print('Australia median age:')
print(mean['Australia'])
# Out:
# United States mean age:
# GenderSelect
# A different identity    39.0
# Female                  34.0
# Male                    37.0
# Name: Age, dtype: float64
#
# India mean age:
# GenderSelect
# A different identity    22.0
# Female                  29.0
# Male                    30.0
# Name: Age, dtype: float64
#
# United Kingdom mean age:
# GenderSelect
# A different identity    36.0
# Female                  34.0
# Male                    36.0
# Name: Age, dtype: float64
#
# Germany mean age:
# GenderSelect
# Female    31.0
# Male      37.0
# Name: Age, dtype: float64
#
# Australia mean age:
# GenderSelect
# Female    35.0
# Male      37.0
# Name: Age, dtype: float64
#
# United States median age:
# GenderSelect
# A different identity    43.0
# Female                  31.0
# Male                    34.0
# Name: Age, dtype: float64
#
# India median age:
# GenderSelect
# A different identity    22.0
# Female                  28.0
# Male                    28.0
# ...

# %% [markdown]
#  <div class="alert alert-block alert-warning">
#
# 13. What Pattern do you notice about the relationship between age, gender for each of these countries?

# %% [markdown]
# <span style="color: green">**Answer**</span>
# By looking at the mean and median ages for each gender of the stated countries, we can conclude that the mean and median age of males are slightly higher than females, and people of different identities are also higher than males and females

# %% [markdown]
# ## 2. Education
# <a id="education"></a>
# ***
# So far we have seen that there may be some relationships between age, gender and the country that the respondents are from.  Next, we should look at what their education is like.
#
# ### 2.1 Formal education
# <a id="formal"></a>
#
# We saw in a recent activity that a significant number of job advertisements call for a masters degree or a PhD. Let's see if this is a reasonable ask based on the respondent's formal education.

# %% [markdown]
#  <div class="alert alert-block alert-info">
#  14. Plot and display as text output the number and percentage of respondents with each type of formal education.

# %%
# Your code
graph = sns.countplot(y=multiple_choice['FormalEducation']).set_title("Bar chart of participants based on formal education")

formal_education = multiple_choice.groupby(['FormalEducation'])
education_occurences = formal_education['FormalEducation'].count()
total_occurences = multiple_choice['Country'].count()
print(education_occurences)
print(total_occurences)
bachelor_percent= round((formal_education['FormalEducation'].count()[0]/total_occurences)*100)
doctoral_percent = round((formal_education['FormalEducation'].count()[1]/total_occurences)*100)
incomplete_percent = round((formal_education['FormalEducation'].count()[2]/total_occurences)*100)
masters_percent = round((formal_education['FormalEducation'].count()[3]/total_occurences)*100)
noformal_percent = round((formal_education['FormalEducation'].count()[4]/total_occurences)*100)
pro_percent = round((formal_education['FormalEducation'].count()[5]/total_occurences)*100)

print("Bachelor's %: " + str(bachelor_percent))
print("Doctoral %: " + str(doctoral_percent))
print("Incomplete university studies %: " + str(incomplete_percent))
print("Masters degree %: " + str(masters_percent))
print("No Formal Education %: " + str(noformal_percent))
print("Professional degree %:" + str(pro_percent))
# Out:
# FormalEducation
# Bachelor's degree                 930
# Doctoral degree                   808
# Incomplete university studies      87
# Master's degree                  1594
# No Formal education                25
# Professional degree                96
# Name: FormalEducation, dtype: int64
# 3540
# Bachelor's %: 26.0
# Doctoral %: 23.0
# Incomplete university studies %: 2.0
# Masters degree %: 45.0
# No Formal Education %: 1.0
# Professional degree %:3.0

# %% [markdown]
#  <div class="alert alert-block alert-warning">
#
# 15. Based on what you have seen, do you think that a Master's or Doctoral degree is too unrealistic for job advertisers looking for someone with data science skills?
#
# Give your reasons.

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Based on the statistics, we can conclude that it is not unrealistic for job advertisers to look for someone with a Masters degree, as most of the survery participants (45%) have a masters degree.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 16. Let's see if the trend is reflected in the Australian respondents.
#
# Plot and display as text output the number and percentage of Australian respondents with each type of formal education.

# %%
# Your code
formal_education_aus = multiple_choice[(multiple_choice['Country'] == 'Australia')].groupby(['FormalEducation'])
australia = multiple_choice[(multiple_choice['Country'] == 'Australia')]
education_occurences_aus = australia['FormalEducation'].count()
graph_ed = sns.countplot(y=australia['FormalEducation']).set_title('Australian respondents bar chart based on education')
print(education_occurences_aus)
bachelors_aus = multiple_choice[(multiple_choice['Country'] == 'Australia') & (multiple_choice['FormalEducation'] == "Bachelor's degree")].groupby('FormalEducation')
doctor_aus = multiple_choice[(multiple_choice['Country'] == 'Australia') & (multiple_choice['FormalEducation'] == "Doctoral degree")].groupby('FormalEducation')
master_aus = multiple_choice[(multiple_choice['Country'] == 'Australia') & (multiple_choice['FormalEducation'] == "Master's degree")].groupby('FormalEducation')
professional_aus = multiple_choice[(multiple_choice['Country'] == 'Australia') & (multiple_choice['FormalEducation'] == "Professional degree")].groupby('FormalEducation')
incomplete_aus = multiple_choice[(multiple_choice['Country'] == 'Australia') & (multiple_choice['FormalEducation'] == "Incomplete university studies")].groupby('FormalEducation')
bachelor_count_aus = bachelors_aus['FormalEducation'].count()
doctor_count_aus = doctor_aus['FormalEducation'].count()
master_count_aus = master_aus['FormalEducation'].count()
professional_count_aus = professional_aus['FormalEducation'].count()
incomplete_count_aus = incomplete_aus['FormalEducation'].count()
bachelor_percentage = round((bachelor_count_aus/education_occurences_aus) * 100)
doctor_percentage = round((doctor_count_aus/education_occurences_aus) * 100)
master_percentage = round((master_count_aus/education_occurences_aus) * 100)
professional_percentage = round((professional_count_aus/education_occurences_aus) * 100)
incomplete_percentage = round((incomplete_count_aus/education_occurences_aus) * 100)
print(bachelor_count_aus)
print(doctor_count_aus)
print(master_count_aus)
print(professional_count_aus)
print(incomplete_count_aus)
print(bachelor_percentage)
print(doctor_percentage)
print(master_percentage)
print(professional_percentage)
print(incomplete_percentage)
# Out:
# 119
# FormalEducation
# Bachelor's degree    45
# Name: FormalEducation, dtype: int64
# FormalEducation
# Doctoral degree    25
# Name: FormalEducation, dtype: int64
# FormalEducation
# Master's degree    42
# Name: FormalEducation, dtype: int64
# FormalEducation
# Professional degree    2
# Name: FormalEducation, dtype: int64
# FormalEducation
# Incomplete university studies    5
# Name: FormalEducation, dtype: int64
# FormalEducation
# Bachelor's degree    38.0
# Name: FormalEducation, dtype: float64
# FormalEducation
# Doctoral degree    21.0
# Name: FormalEducation, dtype: float64
# FormalEducation
# Master's degree    35.0
# Name: FormalEducation, dtype: float64
# FormalEducation
# Professional degree    2.0
# Name: FormalEducation, dtype: float64
# FormalEducation
# Incomplete university studies    4.0
# Name: FormalEducation, dtype: float64

# %% [markdown]
#  <div class="alert alert-block alert-info">
#
# 17. Display as text output the mean and median age of each respondant according to each degree type.

# %%
# Your code
degree_group = multiple_choice.groupby(['FormalEducation'])['Age']
mean_degree = round(degree_group.mean())
median_degree = round(degree_group.median())
print("Mean age based on degree type")
print(mean_degree)
print("")
print("Median age based on degree type")
print(median_degree)
# Out:
# Mean age based on degree type
# FormalEducation
# Bachelor's degree                31.0
# Doctoral degree                  39.0
# Incomplete university studies    36.0
# Master's degree                  34.0
# No Formal education              42.0
# Professional degree              37.0
# Name: Age, dtype: float64
#
# Median age based on degree type
# FormalEducation
# Bachelor's degree                28.0
# Doctoral degree                  37.0
# Incomplete university studies    35.0
# Master's degree                  31.0
# No Formal education              42.0
# Professional degree              34.0
# Name: Age, dtype: float64

# %% [markdown]
# ## 3. Employment
# <a id="employment"></a>
# ***
# After you complete your degree many of you will be seeking work. The graduate employment four months after graduation in Australia is 69.5%. At Monash, it is 70.1%. This is for all Australian degrees. Let's have a look at the state of the employment market for the respondents.
#
# Let's have a look at the data.

# %% [markdown]
# ### 3.1 Employment status
# <a id="employment"></a>
# The type of employment will affect the salary of a worker. Those employed part-time will likely earn less than those who work full time.

# %% [markdown]
#  <div class="alert alert-block alert-info">
#
# 18. Plot the type of employment the respondents have on a bar chart.

# %%
# Your code
employment_graph = sns.countplot(y=multiple_choice['EmploymentStatus']).set_title("Bar Chart based on employment type")

# %% [markdown]
#  <div class="alert alert-block alert-info">
#
# 19. You may be wondering if your own degree and experince will help you gain full time employment after you graduate.
#
# Plot the respondants employment types against their degrees.

# %%
# Your code
ax = sns.countplot(y="EmploymentStatus", hue="MajorSelect", data=multiple_choice).set_title('Bar graph showing employment types against degrees')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 20. Looking at the graph, which degree is best to gain full-time employment?
#
# What is odd about IT, networking or system administration??
#
# Explain your answers.

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Based on the bar graph, Computer Science is the best degree to get a full time employment. IT, networking and system administration surprisingly has lesser job prospects compared to degrees like Mathematics and Computer Science. There are a considerable amount of people who have had other majors of study and are a huge part of the full time employed people

# %% [markdown]
#  <div class="alert alert-block alert-info">
#
# 21. Overall, we know that 92.71% of respondents are employed, and 89.55% are employed full time. This may not be the same for every country.
# Print out the percentages of all respondents who are employed full time in Australia, United Kingdom and the United States.

# %%
# Your code
australia_respondents = multiple_choice[(multiple_choice['Country'] == 'Australia')]
aus_full_time = multiple_choice[(multiple_choice['Country'] == 'Australia') & (multiple_choice['EmploymentStatus'] == 'Employed full-time')]
aus_full_time_count = aus_full_time['EmploymentStatus'].count()
aus_count = australia_respondents['EmploymentStatus'].count()
percent_aus_full_time = round((aus_full_time_count/aus_count) * 100)
UK_respondents = multiple_choice[(multiple_choice['Country'] == 'United Kingdom')]
UK_full_time = multiple_choice[(multiple_choice['Country'] == 'United Kingdom') & (multiple_choice['EmploymentStatus'] == 'Employed full-time')]
UK_full_time_count = UK_full_time['EmploymentStatus'].count()
UK_count = UK_respondents['EmploymentStatus'].count()
UK_percent_full = round((UK_full_time_count/UK_count) * 100)
US_respondents = multiple_choice[(multiple_choice['Country'] == 'United States')]
US_full_time = multiple_choice[(multiple_choice['Country'] == 'United States') & (multiple_choice['EmploymentStatus'] == 'Employed full-time')]
US_full_count = US_full_time['EmploymentStatus'].count()
US_count = US_respondents['EmploymentStatus'].count()
US_percent_full = round((US_full_count/US_count) * 100)

print("Percentage of full time employees in Australia: " + str(percent_aus_full_time))
print(UK_percent_full)
print(US_percent_full)
# Out:
# Percentage of full time employees in Australia: 85.0
# 91.0
# 91.0

# %% [markdown]
# Remember earlier we saw that age seemed to have some interesting characteristics when plotted with other variables.
#
# Let's find out the median age of employees by type of employment.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 22. Plot a boxplot of the respondents age grouped by employment type.

# %%
# Your code
plot = sns.boxplot(x=multiple_choice['Age'], y=multiple_choice['EmploymentStatus'])

# %% [markdown]
# Now this is interesting, full time employees seem to be a little older than part time employees. Independent contactors, freelancers and self-employed respondents are older still.

# %% [markdown]
# ## 4. Salary
# <a id="salary"></a>
#
# Data science is considered a very well paying role and was named 'best job of the year' for 2016.
#
# We had a look around and saw that data scientists were paid between $110,823 at IBM and 149,963 at Apple, in Australian dollars.
#
# On average it seems that $116,840 is what an Australian Data scientist can expect to earn. Do you think this is reasonable? Is this any different to the rest of the world?

# %% [markdown]
# ### 4.1 Salary overview
# <a id="overview"></a>
# Since all of the respondents did not come from one country, we can assume that they gave their salaries in their countries currency. We have filtered the data for you and provided exchange rates in a file called *conversionRates.csv* which should already be imported.
#
# Let's have a look at the data.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 23. Use the codes for each country to merge the files so that you can convert the salary data to Australian Dollars (AUD). Print out the maximum and median salary in AUD. Hint: think about what data type you have.

# %%
# Your code
merge = pd.merge(multiple_choice, conversion_rate, left_on = 'CompensationCurrency', right_on = 'originCountry')
merge['CompensationAmountInAUS'] = round(merge.CompensationAmount * merge.exchangeRateAUS)
ds_salary_AUD = merge[(merge['CurrentJobTitleSelect'] == 'Data Scientist')]
max_ds_salary_AUD = ds_salary_AUD['CompensationAmountInAUS'].max()
median_salary_AUD = ds_salary_AUD['CompensationAmountInAUS'].median()
print(max_ds_salary_AUD)
print(median_salary_AUD)
# Out:
# 790290.0
# 96881.0

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 24. Do those figures reflect the values at the beginning of this section? Why do you think so?

# %% [markdown]
# <span style="color: green">**Answer**</span>
# While looking at the data provided to us, we found out that the maximum a person with the job title "Data Scientist" can earn is AUD 790290, and a median salary of AUD 96881. Thus it does not reflect exactly to the amount mentioned in the beginning of the section, as the actual result is much lower

# %% [markdown]
# ### 4.2 Salary by country
# <a id="countrysal"></a>
#
# Since each country has different cost of living and pay indexes, we should see how they compare.

# %% [markdown]
# <div class="alert alert-block alert-info">
# 25. Plot a boxplot of the Australian respondents salary distribution. Print out the maximum and median salaries for Australian repsondnts.

# %%
# Your code
aus_resp = merge[(merge['Country'] == 'Australia')]
salary_box = sns.boxplot(x=aus_resp['Country'], y=aus_resp['CompensationAmountInAUS']).set_title('Boxplot showing salary distribution of Australian respondents')
max_salary_aus = aus_resp['CompensationAmountInAUS'].max()
median_salary_aus = aus_resp['CompensationAmountInAUS'].median()
print(max_salary_aus)
print(median_salary_aus)
# Out:
# 500000.0
# 120000.0

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 26. Do those figures for Australia reflect the values at the beginning of this section?

# %% [markdown]
# <span style="color: green">**Answer**</span>
# The median salary in Australia according to the result above is AUD 120,000. This seems reasonable and does reflect the values mentioned at the beginning of this section

# %% [markdown]
# <div class="alert alert-block alert-info">
# 27. Australia's salaries look pretty good.
#
# Plot the salaries of all countries on a bar chart.
#
# Hint: Adjust for full-time employees only

# %%
# Your code
full_time = merge[(merge['EmploymentStatus'] == 'Employed full-time')]
full_time_sort = full_time['CompensationAmountInAUS'].sort_values(ascending=False)
bar_plot_sal = sns.barplot(y=full_time['Country'], x=full_time['CompensationAmountInAUS'].sort_values(ascending=False))

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 28. What do you notice about the distributions? What do you think is the cause of this?

# %% [markdown]
# <span style="color: green">**Answer**</span>
# In the above shown bar graph, we can say that countries like UK, USA, and European countries have higher salaries compared to countries in Africa and south east Asia. This can be because the cost of living in certain countries are higher compared to the others and thus pay will be adjusted based on these factors

# %% [markdown]
# ### 4.3 Salary and Gender
# <a id="gender_salary"></a>
# The gender pay gap in the tech industry is a big talking point. Let's see if the respondents are noticing the effect.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
# 29. Plot the salaries of all countries grouped by gender on a boxplot.

# %%
# Your code
gender_salary_box = sns.boxplot(x=merge['GenderSelect'], y=merge['CompensationAmountInAUS']).set_title('Boxplot of salaries based on gender')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 30. What do you notice about the distributions?

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Based on the distributions, we can conclude that the median salaries of males are higher than females and individuals of other identity as per the given dataset

# %% [markdown]
# <div class="alert alert-block alert-info">
# 31. The salaries may be affected by the country the responant is from. In Australia the weekly difference in pay between men and women is 17.7% and in the United states it is 26%.
#
# Print the median salaries of Australia, United States and India grouped by gender.

# %%
# Your code
gender_salary = merge.groupby(['Country','GenderSelect'])
median_gender = gender_salary['CompensationAmountInAUS'].median()
print("Median salary in Australia as per gender")
print(median_gender['Australia'])
print("")
print("Median salary in United States as per gender")
print(median_gender['United States'])
print("")
print("Median salary in India as per gender")
print(median_gender['India'])
# Out:
# Median salary in Australia as per gender
# GenderSelect
# Female     82000.0
# Male      130000.0
# Name: CompensationAmountInAUS, dtype: float64
#
# Median salary in United States as per gender
# GenderSelect
# A different identity    168264.0
# Female                  112176.0
# Male                    143336.0
# Name: CompensationAmountInAUS, dtype: float64
#
# Median salary in India as per gender
# GenderSelect
# A different identity    13628.0
# Female                  12655.0
# Male                    17327.0
# Name: CompensationAmountInAUS, dtype: float64

# %% [markdown]
# ### 4.4 Salary and formal education
# <a id="education_salary"></a>
#
# *Is getting your master's really worth it ?*
# *Do PhDs get more money?*
#
# Let's see.

# %% [markdown]
# <div class="alert alert-block alert-info">
# 32. Plot the salary distribution of all respondants and group by formal education type on a boxplot.

# %%
# Your code
ed_sal_plot = sns.boxplot(y=merge['FormalEducation'], x=merge['CompensationAmountInAUS']).set_title('Boxplot of salaries according to education')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 33. Is it better to get your Masters or PhD?
#
# Explain your answer.

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Based on the above boxplot, we can see that the median salaries of respondents holding a masters degree is slightly more than the respondents with a bachelors degree, and the median salary of respondents with a doctoral degree is higher than that of a masters degree. However, considering some outliers we can also see that there are some respondents with a masters degree who earn more than doctoral degree holders

# %% [markdown]
# ### 4.5 Salary and job
# <a id="salary_job"></a>
# So are data scientists the highest paid in the industry?  Or are there lesser known roles that are hiding from the spotlight?

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# 34. Plot a bar chart of average salary (with error bars) of full time employees and group by job title.

# %%
# Your code
full_time
bar_plot_avg_sal = sns.barplot(x=full_time['CompensationAmountInAUS'], y=full_time['CurrentJobTitleSelect'], hue=full_time['EmploymentStatus']).set_title('Bar chart of average salaries based on job titles')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 35. Which job earns the most? Give a brief explaination of that job.

# %% [markdown]
# <span style="color: green">**Answer**</span>
# As the per the bar graph, an Operations Research Practitioner earns the most. Operations research is the field of study where practitioners research how to make effective decisions. Operations research uses several methods such as mathematical programming and discrete optimisation to fulfil the job

# %% [markdown]
# <div class="alert alert-block alert-info">
# 36. So why are data scientists in the spotlight? Plot the salary distribution of full-time employees and group by job title as boxplots.

# %%
# Your code
full_time
sal_box_job = sns.boxplot(x=full_time['CompensationAmountInAUS'], y=full_time['CurrentJobTitleSelect'],hue=full_time['EmploymentStatus']).set_title('Boxplot to plot distribution of full time employees by job title')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 37. Do the boxplots give some insight into why data scientists may receive so much attention?
#
# Explain your answer.

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Based on the boxplot, we can see that data scientists are having the highest median salary compared to other job roles. Based on this, we can conclude that a role as a data scientist is a more financially secure and can have a lucrative salary if anyone wants to enter in the field.

# %% [markdown]
# ## 5. Predicting salary
# <a id="pred"></a>
#
# We have looked at many variables and seen that there are a lot of factors that could affect your salary.
#
# Let's say we wanted to reduce it though? One method we could use is a linear regression. This is a very basic model that can give us some insights. Note though, there are more robust ways to predict salary based on categorical variables. But this exercise will give you a taste of predictive modelling.

# %% [markdown]
# <div class="alert alert-block alert-info">
# 38. Plot the salary distribution and age of respondants on a scatterplot.

# %%
# Your code
scatter_plot = plt.scatter(x=merge['CompensationAmountInAUS'],y=merge['Age'])

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# 39. There may be a weak relationship. Let's refine this.
#
# Create a linear regression between the salary and age of full-time Australian respondants. Plot the linear fit over the scatterplot.

# %%
#Your code
aus_resp = merge[(merge['Country'] == 'Australia') & (merge['EmploymentStatus'] == 'Employed full-time')]

l_reg = sns.regplot(x=aus_resp['CompensationAmountInAUS'], y=aus_resp['Age']).set_title('Linear Regression between salary and age of full time Australian employees')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# 40. Do You think that this is a good way to predict salaries?
#
# Explain your answer.

# %% [markdown]
# <span style="color: green">**Answer**</span>
# Since a linear regression is generally used for mathematical modelling and predicitive analysis, it is a good way to predict salaries

# %% [markdown]
# Well done you have completed Part A. Don't forget Part B below.
#
# For reassurance, the Graduate Careers Australia 2016 survey found the median salary for masters graduates in Computer Science and IT was $76,000.

# %% [markdown]
# ## Task B - Exploratory Analysis on Other Data
#
# Find some publicly available data and repeat some of the analysis performed in Task A above. Good sources of data are government websites, such as: data.gov.au, data.gov, data.gov.in, data.gov.uk, ...
#
# Please note that your report and analysis should contain consideration of the data you have found and its broader impact in terms of (1) the purpose of the data, (2) ethics and privacy issues, (3) environmental impact, (4) societal benefit, (5) health benefit, and (6) commercial benefit. Moreover, your analysis should at least involve (7) visualisation, (8) interpretation of your visualisation and (9) a prediction task.
#
# To perform Task B, you can continue by extending this jupyter notebook file by adding more cells.

# %% [markdown]
# <span style="color: green">Answer</span>
#
# The dataset I have selected for this part of the assignment is the 'Student Performance in Exams' dataset, developed found on Kaggle. The purpose of this dataset is to assess student exam performance.

# %% [markdown]
# In terms of ethics and privacy issues, the data has been kept open to public use  and there is no limitations mentioned in the terms and conditions regarding the dataset

# %% [markdown]
# This dataset is more of showing students performance in exams based on certain parameters, it can have a social benefit as the readers of this dataset can get an idea as to how student performance in exams can get affected.

# %% [markdown]
# We will first load the dataset into jupyter

# %%
students = pd.read_csv('data/StudentsPerformance.csv')

# %% [markdown]
# In order to visualize this dataset effectively, I think the best way is to have a boxplot of the students who took the exam. One good metric to find out the efeectiveness of student performance is to make a box plot grouped by the gender and also seeing if they completed a test preparation course. The boxplots for each of the 3 examinations are shown below

# %%
box_math = sns.boxplot(x=students['math score'], y =students['gender'] ,hue=students['test preparation course']).set_title('Math scores based on gender and grouped by completion of test prep course')

# %%
box_reading = sns.boxplot(x=students['reading score'], y =students['gender'] ,hue=students['test preparation course']).set_title('Reading scores based on gender and grouped by completion of test prep course')

# %%
box_writing = sns.boxplot(x=students['writing score'], y =students['gender'] ,hue=students['test preparation course']).set_title('Writing scores based on gender and grouped by completion of test prep course')

# %% [markdown]
# As we can see from the above box plots, we can conclude that in general male students are better performers than female students in mathematics, but female students are better in reading and writing examinations. Futhermore, we can also see that the students who completed a test prep course performed better than those who did not complete the course.

# %% [markdown]
# Now we will try to do a linear regression on the dataset, for students who completed a test prep course and their exam scores in reading and writing, as these two courses can be interrelated:

# %%
math_scorers = students[(students['test preparation course'] == 'completed')]

# %%
l_reg_math = sns.regplot(x=math_scorers['writing score'], y=math_scorers['reading score'])

# %% [markdown]
# As we see in the above graph, we can see that by completing a test prep course in reading and writing, there is an increasing trend in both the examination scores, thus making it better for students to perform better in these subjects.
